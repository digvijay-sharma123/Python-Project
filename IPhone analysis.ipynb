# %% [markdown]
# # IPhone Analysis Project

# %% [markdown]
# ## Uploading the csv file

# %%
df=pd.read_csv('iphone.csv')

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# # 1 - The column names have spaces . rename the column names to have underscore '_' instead of space (try to do in one go instead of specifying each column nam in rename method)

# %%
df.columns.str.replace(" ","_",regex=True)
# Out:
# Index(['Product_Name', 'Product_URL', 'Brand', 'Sale_Price', 'Mrp',
#        'Number_Of_Ratings', 'Number_Of_Reviews', 'Upc', 'Star_Rating', 'Ram'],
#       dtype='object')

# %%
df.rename(columns=lambda x: x.replace(" ", "_"), inplace=True)

# %%
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# ## 2- start rating for some of the models is missing in the dataset. fill those missing values with the average rating all the models.

# %%
df['Avg_rating']=df['Star_Rating'].mean()
avg_rating
# Out:
# 4.576271186440678

# %%
fc= (df['Star_Rating'].isna())
df.loc[fc,'Star_Rating']=df.loc[fc,'Avg_rating']

# %%
df.drop(columns='Avg_Rating')
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# ## 3- Now instead of filling missing values with avg rating of full dataset , fill with avg rating based on RAM. example :  if rating for a 2 gb phone is missing then take average of all other 2 gb phones rating and fill that value.

# %%
df2
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df2.columns.str.replace(" ","_",regex=True)
# Out:
# Index(['Product_Name', 'Product_URL', 'Brand', 'Sale_Price', 'Mrp',
#        'Number_Of_Ratings', 'Number_Of_Reviews', 'Upc', 'Star_Rating', 'Ram'],
#       dtype='object')

# %%
df2.rename(columns=lambda x: x.replace(" ", "_"), inplace=True)

# %%
df2
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df2['Star_Rating'].fillna(df.groupby('Ram')['Star_Rating'].transform('mean'), inplace=True)

# %%
df2
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# ## 4- create a new column in the dataframe "Discount_Percentage" based on MRP and sale value

# %%
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
fc = (df['Sale_Price']<=df['Mrp'])
df.loc[fc,'Discount_Percentage']= 100.00*(df['Mrp']-df['Sale_Price'])/(df['Mrp'])

# %%
fc = (df['Sale_Price']>df['Mrp'])
df.loc[fc,'Discount_Percentage']= 100.00*(df['Mrp']-df['Sale_Price'])/(df['Mrp'])

# %%
df.drop(columns='Dicount_Percentage',inplace=True)

# %%
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# ## 5- which model has highest percent discount ?

# %%
fc = df['Discount_Percentage']==df['Discount_Percentage'].max()
df.loc[fc,'Product_Name']
# Out:
# 18    APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# Name: Product_Name, dtype: object

# %%
df.iloc[18]
# Out:
# Product_Name                 APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# Product_URL            https://www.flipkart.com/apple-iphone-11-pro-m...
# Brand                                                              Apple
# Sale_Price                                                         74999
# Mrp                                                               106600
# Number_Of_Ratings                                                   7088
# Number_Of_Reviews                                                    523
# Upc                                                     MOBFKCTSN3TG3RFJ
# Star_Rating                                                          4.6
# Ram                                                                 4 GB
# Avg_Rating                                                           NaN
# Avg_rating                                                      4.576271
# Discount_Percentage                                            29.644465
# ...

# %% [markdown]
# ## 6- find total no of models  each space configuration (128 GB , 64 GB etc)

# %%
df['Space_Configuration']=df['Product_Name'].str.extract(r'(\d+\s*GB)')

# %%
df['Space_Configuration'].value_counts()
# Out:
# 128 GB    24
# 64 GB     20
# 256 GB    14
# 512 GB     4
# Name: Space_Configuration, dtype: int64

# %% [markdown]
# ## 7- find total number of models for each color

# %%
df['Model_Color']=df['Product_Name'].str.extract(r'\(([^,]+),')

# %%
df['Model_Color'].value_counts()
# Out:
# Black             10
# White             10
# Silver             7
# Gold               6
# Space Grey         6
# Red                5
# Midnight Green     4
# Pacific Blue       4
# Graphite           4
# Blue               2
# RED                1
# Coral              1
# Green              1
# Purple             1
# Name: Model_Color, dtype: int64

# %% [markdown]
# ## 8- find total number of models by iphone version

# %%
df['Model_Name'] = df['Product_Name'].str.extract(r'^(.*?)\s?\(')

# %%
df['Model_Name'].value_counts()
# Out:
# APPLE iPhone 12 Pro Max    8
# APPLE iPhone 12            7
# APPLE iPhone 11            7
# APPLE iPhone 12 Mini       6
# APPLE iPhone 8 Plus        5
# Apple iPhone XR            5
# APPLE iPhone 11 Pro Max    5
# APPLE iPhone 12 Pro        5
# APPLE iPhone SE            5
# APPLE iPhone 11 Pro        4
# APPLE iPhone 8             3
# APPLE iPhone XS Max        1
# Apple iPhone SE            1
# Name: Model_Name, dtype: int64

# %% [markdown]
# ## 9- list top 5 models having highest no of reviews

# %%
df.groupby('Product_Name')['Number_Of_Reviews'].max().head(5)
# Out:
# Product_Name
# APPLE iPhone 11 (Black, 128 GB)    3331
# APPLE iPhone 11 (Black, 64 GB)     3331
# APPLE iPhone 11 (Purple, 64 GB)    3331
# APPLE iPhone 11 (Red, 128 GB)      3357
# APPLE iPhone 11 (Red, 64 GB)       3331
# Name: Number_Of_Reviews, dtype: int64

# %% [markdown]
# ## 10 - what is the price diffrence between highest price and lowest price iphone (based on mrp)

# %%
max= df['Mrp'].max()
min= df['Mrp'].min()
print("Max Price:",max,"\nMin Price:",min,"\nDelta:",max-min)
# Out:
# Max Price: 149900
# Min Price: 39900
# Delta: 110000

# %% [markdown]
# ## 11 - find total no of reviews for iphone 11 and iphone 12 category . Output should have only 2 rows (for 11 and 12).

# %%
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
fc = (df['Model_Name'] == 'APPLE iPhone 11')
df.loc[fc, 'Number_Of_Reviews'].sum()
# Out:
# 23369

# %%
fc = (df['Model_Name'] == 'APPLE iPhone 12')
df.loc[fc, 'Number_Of_Reviews'].sum()
# Out:
# 1256

# %% [markdown]
# ## 12- which iphone has 3rd highest MRP

# %%
df.sort_values(by='Mrp',ascending=False,inplace=True)
df.reset_index()
df.iloc[2]
# Out:
# Product_Name                APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# Product_URL            https://www.flipkart.com/apple-iphone-11-pro-m...
# Brand                                                              Apple
# Sale_Price                                                        117900
# Mrp                                                               140300
# Number_Of_Ratings                                                   7088
# Number_Of_Reviews                                                    523
# Upc                                                     MOBFKCTSSJCWYGCC
# Star_Rating                                                          4.6
# Ram                                                                 4 GB
# Avg_Rating                                                           NaN
# Avg_rating                                                      4.576271
# Discount_Percentage                                            15.965788
# ...

# %% [markdown]
# ## 13- what is the average mrp of iphones which costs above 100,000

# %%
fc = df['Mrp']>100000
df.loc[fc,'Mrp'].mean()
# Out:
# 130559.09090909091

# %% [markdown]
# ## 14- which iphone with 128 GB space has highest ratings to review ratio

# %%
df['Ratio']= df['Star_Rating']/df['Number_Of_Reviews']
fc = (df['Space_Configuration']=='128 GB')
fc2=df.loc[fc,['Ratio','Model_Name']].max()
fc2
# Out:
# Ratio                0.107143
# Model_Name    Apple iPhone XR
# dtype: object
